# %%
#Written Soheil Danesh (soheildb@gmail.com, github username: soheildanesh )



import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)



readDictionary = r"C:\Users\sdanesh\Documents\hackathon\taxon.txt"
f = open(readDictionary, encoding = "ISO-8859-1")

stopwords = ["a", "about", "above", "above", "across", "after", "afterwards", "again", "against", "all", "almost", "alone", "along", "already", "also","although","always","am","among", "amongst", "amoungst", "amount",  "an", "and", "another", "any","anyhow","anyone","anything","anyway", "anywhere", "are", "around", "as",  "at", "back","be","became", "because","become","becomes", "becoming", "been", "before", "beforehand", "behind", "being", "below", "beside", "besides", "between", "beyond", "bill", "both", "bottom","but", "by", "call", "can", "cannot", "cant", "co", "con", "could", "couldnt", "cry", "de", "describe", "detail", "do", "done", "down", "due", "during", "each", "eg", "eight", "either", "eleven","else", "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone", "everything", "everywhere", "except", "few", "fifteen", "fify", "fill", "find", "fire", "first", "five", "for", "former", "formerly", "forty", "found", "four", "from", "front", "full", "further", "get", "give", "go", "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter", "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his", "how", "however", "hundred", "ie", "if", "in", "inc", "indeed", "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter", "latterly", "least", "less", "ltd", "made", "many", "may", "me", "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly", "move", "much", "must", "my", "myself", "name", "namely", "neither", "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone", "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on", "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our", "ours", "ourselves", "out", "over", "own","part", "per", "perhaps", "please", "put", "rather", "re", "same", "see", "seem", "seemed", "seeming", "seems", "serious", "several", "she", "should", "show", "side", "since", "sincere", "six", "sixty", "so", "some", "somehow", "someone", "something", "sometime", "sometimes", "somewhere", "still", "such", "system", "take", "ten", "than", "that", "the", "their", "them", "themselves", "then", "thence", "there", "thereafter", "thereby", "therefore", "therein", "thereupon", "these", "they", "thickv", "thin", "third", "this", "those", "though", "three", "through", "throughout", "thru", "thus", "to", "together", "too", "top", "toward", "towards", "twelve", "twenty", "two", "un", "under", "until", "up", "upon", "us", "very", "via", "was", "we", "well", "were", "what", "whatever", "when", "whence", "whenever", "where", "whereafter", "whereas", "whereby", "wherein", "whereupon", "wherever", "whether", "which", "while", "whither", "who", "whoever", "whole", "whom", "whose", "why", "will", "with", "within", "without", "would", "yet", "you", "your", "yours", "yourself", "yourselves", "the"]

# %%
import re

n = 0
terms_dict = {}

for line in f:
    n += 1
    #term_to_uri[]

    if False: #remember to take the prints out if you make this false otherwise big pring out and notebook hangs
        if(n > 400):
            break
    #print(line.split())
    #splitLine = line.split("\s|;")
    splitLine = re.split("\s|;", line)
    uri = splitLine[0]
    #print("splitLine = "+str(splitLine))
    
    if(len(splitLine[1:]) > 1):
        term = " ".join(splitLine[1:])
        termAndWords = splitLine[1:]
        termAndWords.append(term)
        #print(term)
        #terms_dict[term] = uri
    
    for word in termAndWords:
        if(len(word) < 4 or (word in stopwords)):
            #print(word)
            next
            
        #print(word)
        
        if word in terms_dict:
            curCount = terms_dict[word]['count']
            terms_dict[word] = {"uri": uri, "count": curCount+1}
        else:
            terms_dict[word] = {"uri": uri, "count": 1}

print(len(terms_dict))
# Out:
# 3042808

# %%
text = "Single nucleus RNA-seq of cell diversity in the adult mouse hippocampus. Habib N, Li Y, Heidenreich M, Swiech L, Avraham-Davidi I, Trombetta J, Hession C, Zhang F, Regev A. Div-Seq: Single-nucleus RNA-Seq reveals dynamics of rare adult newborn neurons. Science  28 Jul 2016 DOI: 10.1126/science.aad7038 Contact: naomi@broadinstitute.org Single cell RNA-Seq provides rich information about cell types and states. However, it is difficult to capture rare dynamic processes, such as adult neurogenesis, because isolation of rare neurons from adult tissue is challenging and markers for each phase are limited. Here, we develop Div-Seq, which combines scalable single-nucleus RNA-Seq (sNuc-Seq) with pulse labeling of proliferating cells by EdU to profile individual dividing cells. sNuc-Seq and Div-Seq can sensitively identify closely related hippocampal cell types and track transcriptional dynamics of newborn neurons within the adult hippocampal neurogenic niche, respectively. This study contains the sNuc-Seq analysis performed as a part of the Div-Seq method development. Using sNuc-Seq, we analyzed 1,367 single nuclei from hippocampal anatomical sub-regions (DG, CA1, CA2, and CA3) from adult mice, including enrichment of genetically-tagged lowly abundant GABAergic neurons (9). sNuc-Seq robustly generated high quality data across animal age groups (including 2 years old mice), detecting 5,100 expressed genes per nucleus on average, with comparable complexity to single neuron RNA-Seq from young mice (1, 2, 3). Analysis of sNuc-Seq data revealed distinct nuclei clusters (Fig. 1B-D shown below) corresponding to known cell types and anatomical distinctions in the hippocampus."

# %%
terms_seen = []
for term in terms_dict:
    if(" "+term+" " in text):
        terms_seen.append(term)
        
print(len(terms_seen))
# Out:
# 42

# %%
good_terms = []
for term in terms_seen:
    if(not term.lower() in stopwords):
        good_terms.append(term)
        

print(terms_seen)
print(good_terms)
# Out:
# ['', 'of', 'and', 'high', 'mice', 'old', 'mouse', '2', 'single', 'with', 'cell', 'the', '28', 'from', 'nucleus', 'enrichment', 'on', 'a', 'Zhang', 'related', 'in', 'track', 'This', 'types', 'Li', 'A.', 'tissue', 'to', 'rare', 'Single', 'Analysis', 'lowly', '2016', 'age', 'analysis', 'revealed', 'for', 'by', 'young', 'capture', 'M,', 'per']
# ['', 'high', 'mice', 'old', 'mouse', '2', 'single', 'cell', '28', 'nucleus', 'enrichment', 'Zhang', 'related', 'track', 'types', 'Li', 'A.', 'tissue', 'rare', 'Single', 'Analysis', 'lowly', '2016', 'age', 'analysis', 'revealed', 'young', 'capture', 'M,']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
#nltk.download('tokenizers/punkt/english.pickle')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sdanesh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sdanesh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
tokenizedText = nltk.word_tokenize(text)
nltk.pos_tag(tokenizedText)
# Out:
# [('Single', 'NNP'),
#  ('nucleus', 'JJ'),
#  ('RNA-seq', 'NNP'),
#  ('of', 'IN'),
#  ('cell', 'NN'),
#  ('diversity', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('adult', 'NN'),
#  ('mouse', 'NN'),
#  ('hippocampus', 'NN'),
#  ('.', '.'),
#  ('Habib', 'NNP'),
#  ('N', 'NNP'),
#  (',', ','),
#  ('Li', 'NNP'),
#  ('Y', 'NNP'),
#  (',', ','),
#  ('Heidenreich', 'NNP'),
#  ('M', 'NNP'),
#  (',', ','),
#  ('Swiech', 'NNP'),
#  ('L', 'NNP'),
#  (',', ','),
#  ('Avraham-Davidi', 'NNP'),
#  ('I', 'PRP'),
#  (',', ','),
#  ('Trombetta', 'NNP'),
#  ('J', 'NNP'),
#  (',', ','),
#  ('Hession', 'NNP'),
#  ('C', 'NNP'),
#  (',', ','),
#  ('Zhang', 'NNP'),
#  ('F', 'NNP'),
#  (',', ','),
#  ('Regev', 'NNP'),
#  ('A.', 'NN'),
#  ('Div-Seq', 'NNP'),
#  (':', ':'),
#  ('Single-nucleus', 'JJ'),
#  ('RNA-Seq', 'JJ'),
#  ('reveals', 'NNS'),
#  ('dynamics', 'NNS'),
#  ('of', 'IN'),
#  ('rare', 'JJ'),
#  ('adult', 'NN'),
#  ('newborn', 'JJ'),
#  ('neurons', 'NNS'),
#  ('.', '.'),
#  ('Science', 'NN'),
#  ('28', 'CD'),
#  ('Jul', 'NNP'),
#  ('2016', 'CD'),
#  ('DOI', 'NNP'),
#  (':', ':'),
#  ('10.1126/science.aad7038', 'CD'),
#  ('Contact', 'NN'),
#  (':', ':'),
#  ('naomi', 'JJ'),
#  ('@', 'NNP'),
#  ('broadinstitute.org', 'NN'),
#  ('Single', 'NNP'),
#  ('cell', 'NN'),
#  ('RNA-Seq', 'NNP'),
#  ('provides', 'VBZ'),
#  ('rich', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('cell', 'NN'),
#  ('types', 'NNS'),
#  ('and', 'CC'),
#  ('states', 'NNS'),
#  ('.', '.'),
#  ('However', 'RB'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('difficult', 'JJ'),
#  ('to', 'TO'),
#  ('capture', 'VB'),
#  ('rare', 'JJ'),
#  ('dynamic', 'JJ'),
#  ('processes', 'NNS'),
#  (',', ','),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('adult', 'NN'),
#  ('neurogenesis', 'NN'),
#  (',', ','),
#  ('because', 'IN'),
#  ('isolation', 'NN'),
#  ('of', 'IN'),
#  ('rare', 'JJ'),
#  ('neurons', 'NNS'),
#  ('from', 'IN'),
#  ('adult', 'NN'),
#  ('tissue', 'NN'),
#  ('is', 'VBZ'),
#  ('challenging', 'VBG'),
#  ('and', 'CC'),
#  ('markers', 'NNS'),
#  ('for', 'IN'),
#  ('each', 'DT'),
#  ('phase', 'NN'),
#  ('are', 'VBP'),
#  ('limited', 'VBN'),
#  ('.', '.'),
#  ('Here', 'RB'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('develop', 'VBP'),
#  ('Div-Seq', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('combines', 'VBZ'),
#  ('scalable', 'JJ'),
#  ('single-nucleus', 'JJ'),
#  ('RNA-Seq', 'NNP'),
#  ('(', '('),
#  ('sNuc-Seq', 'JJ'),
#  (')', ')'),
#  ('with', 'IN'),
#  ('pulse', 'JJ'),
#  ('labeling', 'NN'),
#  ('of', 'IN'),
#  ('proliferating', 'VBG'),
#  ('cells', 'NNS'),
#  ('by', 'IN'),
#  ('EdU', 'NNP'),
#  ('to', 'TO'),
#  ('profile', 'VB'),
#  ('individual', 'JJ'),
#  ('dividing', 'NN'),
#  ('cells', 'NNS'),
#  ('.', '.'),
#  ('sNuc-Seq', 'JJ'),
#  ('and', 'CC'),
#  ('Div-Seq', 'NNP'),
#  ('can', 'MD'),
#  ('sensitively', 'RB'),
#  ('identify', 'VB'),
#  ('closely', 'RB'),
#  ('related', 'JJ'),
#  ('hippocampal', 'NN'),
#  ('cell', 'NN'),
#  ('types', 'NNS'),
#  ('and', 'CC'),
#  ('track', 'NN'),
#  ('transcriptional', 'JJ'),
#  ('dynamics', 'NNS'),
#  ('of', 'IN'),
#  ('newborn', 'JJ'),
#  ('neurons', 'NNS'),
#  ('within', 'IN'),
#  ('the', 'DT'),
#  ('adult', 'NN'),
#  ('hippocampal', 'JJ'),
#  ('neurogenic', 'JJ'),
#  ('niche', 'NN'),
#  (',', ','),
#  ('respectively', 'RB'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('study', 'NN'),
#  ('contains', 'VBZ'),
#  ('the', 'DT'),
#  ('sNuc-Seq', 'JJ'),
#  ('analysis', 'NN'),
#  ('performed', 'VBN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Div-Seq', 'NNP'),
#  ('method', 'NN'),
#  ('development', 'NN'),
#  ('.', '.'),
#  ('Using', 'VBG'),
#  ('sNuc-Seq', 'JJ'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('analyzed', 'VBD'),
#  ('1,367', 'CD'),
#  ('single', 'JJ'),
#  ('nuclei', 'NN'),
#  ('from', 'IN'),
#  ('hippocampal', 'JJ'),
#  ('anatomical', 'JJ'),
#  ('sub-regions', 'NNS'),
#  ('(', '('),
#  ('DG', 'NNP'),
#  (',', ','),
#  ('CA1', 'NNP'),
#  (',', ','),
#  ('CA2', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('CA3', 'NNP'),
#  (')', ')'),
#  ('from', 'IN'),
#  ('adult', 'NN'),
#  ('mice', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('enrichment', 'NN'),
#  ('of', 'IN'),
#  ('genetically-tagged', 'JJ'),
#  ('lowly', 'NN'),
#  ('abundant', 'JJ'),
#  ('GABAergic', 'NNP'),
#  ('neurons', 'NNS'),
#  ('(', '('),
#  ('9', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('sNuc-Seq', 'JJ'),
#  ('robustly', 'RB'),
#  ('generated', 'VBN'),
#  ('high', 'JJ'),
#  ('quality', 'NN'),
#  ('data', 'NNS'),
#  ('across', 'IN'),
#  ('animal', 'JJ'),
#  ('age', 'NN'),
#  ('groups', 'NNS'),
#  ('(', '('),
#  ('including', 'VBG'),
#  ('2', 'CD'),
#  ('years', 'NNS'),
#  ('old', 'JJ'),
#  ('mice', 'NN'),
#  (')', ')'),
#  (',', ','),
#  ('detecting', 'VBG'),
#  ('5,100', 'CD'),
#  ('expressed', 'VBN'),
#  ('genes', 'NNS'),
#  ('per', 'IN'),
#  ('nucleus', 'NN'),
#  ('on', 'IN'),
#  ('average', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('comparable', 'JJ'),
#  ('complexity', 'NN'),
#  ('to', 'TO'),
#  ('single', 'JJ'),
#  ('neuron', 'JJ'),
#  ('RNA-Seq', 'NN'),
#  ('from', 'IN'),
#  ('young', 'JJ'),
#  ('mice', 'NN'),
#  ('(', '('),
#  ('1', 'CD'),
#  (',', ','),
#  ('2', 'CD'),
#  (',', ','),
#  ('3', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('Analysis', 'NN'),
#  ('of', 'IN'),
#  ('sNuc-Seq', 'JJ'),
#  ('data', 'NNS'),
#  ('revealed', 'VBD'),
#  ('distinct', 'JJ'),
#  ('nuclei', 'JJ'),
#  ('clusters', 'NNS'),
#  ('(', '('),
#  ('Fig', 'NNP'),
#  ('.', '.'),
#  ('1B-D', 'JJ'),
#  ('shown', 'VBN'),
#  ('below', 'IN'),
#  (')', ')'),
#  ('corresponding', 'VBG'),
#  ('to', 'TO'),
#  ('known', 'VBN'),
#  ('cell', 'NN'),
#  ('types', 'NNS'),
#  ('and', 'CC'),
#  ('anatomical', 'JJ'),
#  ('distinctions', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('hippocampus', 'NN'),
#  ('.', '.')]
